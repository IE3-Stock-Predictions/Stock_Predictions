# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error

stocks = pd.read_csv("~/Stock_Prediction_ML/StockPredictions/Stock_Predictions/data/S&P_500_GOOGFIN_3MO.csv")
# Out:
# Using TensorFlow backend.

# %%
def get_stock_data(name):
    return stocks.loc[stocks['Stock'] == name]

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
AAPL = get_stock_data('AAPL')

plt.plot(AAPL.Date, AAPL.High, 'r--', AAPL.Date, AAPL.Close, 'b--')
# Out:
# [<matplotlib.lines.Line2D at 0x103a10390>,
#  <matplotlib.lines.Line2D at 0x103a1a3d0>]

# %%
u_stocks = np.unique(stocks['Stock'])
labels, uniques = pd.factorize(stocks['Stock'])
labels.transpose
stocks['ID'] = labels
stocks_id = stocks.drop(['Stock'], axis = 1)
print(stocks_id)
AAPL = AAPL.set_index('Date')
AAPL = AAPL.drop(['Stock'], axis = 1)
print(AAPL)
AAPL_val = AAPL.values
AAPL_val = AAPL_val.astype('float64')
# Out:
#         Date    Open    High     Low   Close   Volume   ID
# 0      43756   74.00   74.82   73.77   74.57  2121895    0
# 1      43759   74.88   75.51   74.69   75.48  1739523    0
# 2      43760   75.68   76.33   74.64   74.69  1327981    0
# 3      43761   75.02   75.89   74.68   74.98  1828337    0
# 4      43762   75.03   75.11   74.46   75.00  1582478    0
# ...      ...     ...     ...     ...     ...      ...  ...
# 31810  43843  136.07  136.75  135.46  136.51  1801255  514
# 31811  43844  136.42  137.28  135.52  137.27  1848833  514
# 31812  43845  137.41  139.00  137.34  138.54  1859576  514
# 31813  43846  138.78  139.40  138.02  139.24  1822882  514
# 31814  43847  139.62  140.40  138.86  140.16  1993175  514
#
# [31815 rows x 7 columns]
#          Open    High     Low   Close    Volume
# Date
# 43756  234.59  237.58  234.29  236.41  24377166
# 43759  237.52  240.99  237.32  240.51  22367483
# 43760  241.16  242.20  239.62  239.96  22684001
# 43761  242.10  243.24  241.22  243.18  19932545
# 43762  244.51  244.80  241.81  243.58  17916255
# ...       ...     ...     ...     ...       ...
# 43843  311.64  317.07  311.15  316.96  30521722
# 43844  316.70  317.57  312.17  312.68  40653457
# 43845  311.85  315.50  309.55  311.34  30480882
# 43846  313.59  315.70  312.09  315.24  27207254
# 43847  316.27  318.74  315.00  318.73  34454117
#
# [63 rows x 5 columns]

# %%
groups = [0, 1, 2, 3, 4]
i = 1
# plot each column
plt.figure()
for group in groups:
    plt.subplot(len(groups), 1, i)
    plt.plot(AAPL_val[:, group])
    plt.title(AAPL.columns[group], y=0.5, loc='right')
    i += 1
plt.show()

# %%
scaler = MinMaxScaler(feature_range=(0,1))
scaled = scaler.fit_transform(AAPL_val)
reframed = series_to_supervised(scaled, 1, 1)
reframed.drop(reframed.columns[[6, 7, 8, 9]], axis=1, inplace=True)
print(reframed.head())
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)   var1(t)
# 1   0.000000   0.000000   0.000000   0.000000   0.221735  0.035684
# 2   0.035684   0.042016   0.037542   0.049806   0.186710  0.080015
# 3   0.080015   0.056925   0.066039   0.043124   0.192226  0.091463
# 4   0.091463   0.069739   0.085863   0.082240   0.144274  0.120814
# 5   0.120814   0.088960   0.093173   0.087099   0.109133  0.104372

# %%
values = reframed.values

# %%
n_train = int(values.shape[0] * 0.67)
train = values[:n_train,:]
test = values[n_train:,:]

# %%
X_train, y_train = train[:, :-1], train[:, -1]
X_test, y_test = test[:, :-1], test[:, -1]

# %%
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (41, 1, 5) (41,) (21, 1, 5) (21,)

# %%
model = Sequential()
model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
history = model.fit(X_train, y_train, epochs=50, batch_size=20, validation_data=(X_test, y_test), verbose=2,shuffle=False)
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()
# Out:
# Train on 41 samples, validate on 21 samples
# Epoch 1/50
#  - 2s - loss: 0.3136 - val_loss: 0.7478
# Epoch 2/50
#  - 0s - loss: 0.2910 - val_loss: 0.7075
# Epoch 3/50
#  - 0s - loss: 0.2685 - val_loss: 0.6670
# Epoch 4/50
#  - 0s - loss: 0.2462 - val_loss: 0.6260
# Epoch 5/50
#  - 0s - loss: 0.2240 - val_loss: 0.5845
# Epoch 6/50
#  - 0s - loss: 0.2017 - val_loss: 0.5423
# Epoch 7/50
#  - 0s - loss: 0.1791 - val_loss: 0.4991
# Epoch 8/50
#  - 0s - loss: 0.1575 - val_loss: 0.4553
# Epoch 9/50
#  - 0s - loss: 0.1371 - val_loss: 0.4105
# Epoch 10/50
#  - 0s - loss: 0.1172 - val_loss: 0.3650
# Epoch 11/50
#  - 0s - loss: 0.0990 - val_loss: 0.3188
# Epoch 12/50
#  - 0s - loss: 0.0824 - val_loss: 0.2718
# Epoch 13/50
#  - 0s - loss: 0.0669 - val_loss: 0.2240
# Epoch 14/50
#  - 0s - loss: 0.0533 - val_loss: 0.1784
# Epoch 15/50
#  - 0s - loss: 0.0461 - val_loss: 0.1370
# Epoch 16/50
#  - 0s - loss: 0.0490 - val_loss: 0.1018
# Epoch 17/50
#  - 0s - loss: 0.0597 - val_loss: 0.0762
# Epoch 18/50
#  - 0s - loss: 0.0706 - val_loss: 0.0681
# Epoch 19/50
#  - 0s - loss: 0.0733 - val_loss: 0.0729
# Epoch 20/50
#  - 0s - loss: 0.0662 - val_loss: 0.0861
# Epoch 21/50
#  - 0s - loss: 0.0586 - val_loss: 0.0971
# Epoch 22/50
#  - 0s - loss: 0.0535 - val_loss: 0.1034
# Epoch 23/50
#  - 0s - loss: 0.0505 - val_loss: 0.1054
# Epoch 24/50
#  - 0s - loss: 0.0487 - val_loss: 0.1038
# Epoch 25/50
#  - 0s - loss: 0.0478 - val_loss: 0.0994
# Epoch 26/50
#  - 0s - loss: 0.0476 - val_loss: 0.0933
# Epoch 27/50
#  - 0s - loss: 0.0478 - val_loss: 0.0861
# Epoch 28/50
#  - 0s - loss: 0.0485 - val_loss: 0.0784
# Epoch 29/50
#  - 0s - loss: 0.0494 - val_loss: 0.0717
# Epoch 30/50
#  - 0s - loss: 0.0502 - val_loss: 0.0659
# Epoch 31/50
#  - 0s - loss: 0.0512 - val_loss: 0.0651
# Epoch 32/50
#  - 0s - loss: 0.0492 - val_loss: 0.0707
# Epoch 33/50
#  - 0s - loss: 0.0456 - val_loss: 0.0734
# Epoch 34/50
#  - 0s - loss: 0.0433 - val_loss: 0.0730
# Epoch 35/50
#  - 0s - loss: 0.0421 - val_loss: 0.0702
# Epoch 36/50
#  - 0s - loss: 0.0415 - val_loss: 0.0656
# Epoch 37/50
#  - 0s - loss: 0.0415 - val_loss: 0.0606
# Epoch 38/50
#  - 0s - loss: 0.0418 - val_loss: 0.0556
# Epoch 39/50
#  - 0s - loss: 0.0426 - val_loss: 0.0543
# Epoch 40/50
#  - 0s - loss: 0.0410 - val_loss: 0.0584
# Epoch 41/50
#  - 0s - loss: 0.0382 - val_loss: 0.0594
# Epoch 42/50
#  - 0s - loss: 0.0366 - val_loss: 0.0574
# Epoch 43/50
#  - 0s - loss: 0.0359 - val_loss: 0.0533
# Epoch 44/50
#  - 0s - loss: 0.0358 - val_loss: 0.0495
# Epoch 45/50
#  - 0s - loss: 0.0365 - val_loss: 0.0481
# Epoch 46/50
#  - 0s - loss: 0.0355 - val_loss: 0.0499
# Epoch 47/50
#  - 0s - loss: 0.0333 - val_loss: 0.0498
# Epoch 48/50
#  - 0s - loss: 0.0321 - val_loss: 0.0477
# Epoch 49/50
#  - 0s - loss: 0.0317 - val_loss: 0.0470
# Epoch 50/50
#  - 0s - loss: 0.0309 - val_loss: 0.0495

# %%
# make a prediction
print(X_test.shape)
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))
y_pred = model.predict(X_test)
X_test = X_test.reshape((X_test.shape[0], X_test.shape[2]))
# invert scaling for forecast
inv_y_pred = np.concatenate((y_pred, X_test[:,1:]), axis=1)
inv_y_pred = scaler.inverse_transform(inv_y_pred)
inv_y_pred = inv_y_pred[:, 0]
# invert scaling for actual
y_test = y_test.reshape((len(y_test), 1))
inv_y = np.concatenate((y_test, X_test[:, 1:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]

rmse = math.sqrt(mean_squared_error(inv_y, inv_y_pred))
print('Test RMSE: %.3f' % rmse)
# Out:
# (21, 5)
# Test RMSE: 4.939

# %%
print(inv_y_pred)
# Out:
# [279.29921746 279.358877   278.10865982 289.38152222 280.39215665
#  278.71353604 284.59056304 290.55236628 289.76498767 288.66213296
#  296.56578799 296.83711407 294.38538616 295.60330203 298.75269412
#  307.87118661 307.78427162 310.33017253 313.07618002 308.15520808
#  309.06881139]

# %%
print(inv_y)
# Out:
# [279.8  279.5  282.23 280.53 284.69 284.82 291.12 289.46 289.93 296.24
#  297.15 293.79 299.84 297.16 307.24 310.6  311.64 316.7  311.85 313.59
#  316.27]

# %%
# Out:
# [[0.54780173 0.54448004 0.55148061 0.53449951 0.2949096 ]
#  [0.55060285 0.54608181 0.55544542 0.52636054 0.30273291]
#  [0.54694921 0.53721045 0.55333912 0.5297619  0.22608836]
#  [0.5801973  0.55532282 0.548507   0.52271623 1.        ]
#  [0.55949336 0.57503696 0.57093297 0.57810982 0.22697608]
#  [0.61015711 0.58292262 0.60252757 0.5813897  0.00811022]
#  [0.61174035 0.64563825 0.62458184 0.64990282 0.20355474]
#  [0.68846669 0.69480039 0.66695577 0.64856657 0.43463362]
#  [0.66824991 0.67902908 0.63102466 0.66946064 0.42533879]
#  [0.67397394 0.69122721 0.68430182 0.69533528 0.23690564]
#  [0.75082207 0.77649088 0.75455334 0.77672498 0.38790745]
#  [0.76190476 0.77624446 0.77078429 0.74125364 0.43534716]
#  [0.72098405 0.76860522 0.72432165 0.77004373 0.31353763]
#  [0.79466569 0.78018728 0.78292653 0.75291545 0.28274225]
#  [0.76202655 0.82380483 0.77896171 0.81122449 0.37360035]
#  [0.8847887  0.89760966 0.89096766 0.88945578 0.53970117]
#  [0.92570941 0.92520946 0.91636724 0.89795918 0.41065832]
#  [0.93837535 0.97942336 0.95229835 0.97849854 0.32882349]
#  [1.         0.98558403 0.96493619 0.92650632 0.50540106]
#  [0.94093289 0.96007886 0.93247429 0.91022838 0.32811172]
#  [0.96212398 0.96254312 0.96394499 0.95760447 0.27105838]]

# %%
plt.plot(range(inv_y.shape[0]),inv_y, label='actual')
plt.plot(range(inv_y_pred.shape[0]), inv_y_pred, label='predicted')
plt.legend()
plt.show()
